# %%
import copy

class Solution:

    def findMaxForm(self, strs, m, n):
        numOne = 0
        numZero = 0
        strList = copy.deepcopy(strs)
        stop_for = None
        

        def lenghtValue(list_One_Zero):
            list = []
            for value in list_One_Zero:
                list.append(len(value))

            print("list",list)
            return list
        
        listLenghtValue = lenghtValue(strList)

        while True:

            print("stop_for in while", stop_for)

            if stop_for:
                break

            print (listLenghtValue, "listLenghtValue")

            for elementStrs in strs:

                print("stop_for in element boucle", stop_for)
                if stop_for:
                    break

                smallest = min(listLenghtValue)

                print ("len element",len(elementStrs))
                print ("smallest", smallest)

                if len(elementStrs) <= smallest:

                    if stop_for:
                        break

                    print ('number treat////////////', elementStrs)
                    for number in elementStrs:
                        print ("elementstr", strs)
                        
                        print('number in number treat', number)
                        if numZero < m:
                            if number == "0":
                                print("add zero")
                                numZero += 1
                        if numOne < n:
                            if number == "1":
                                print ("add one")
                                numOne += 1

                        if numZero == m and numOne == n:
                            print("we break because of num")
                            stop_for = True
                            break
                    print()
                    print ("smallest in for", smallest)
                    print ("list leght", listLenghtValue)
                    print ("strList", strList)
                    print ("elment str", elementStrs)
                    print ()

                    listLenghtValue.remove(smallest)
                    strList.remove(elementStrs)

                    if len(listLenghtValue) == 0:
                        stop_for = True
                        print ("we break because of lenght")
                    
                print()
                print("num one", numOne)
                print("num zero", numZero)
                print()


        resultat = [item for item in strs if item not in strList]
        return len(resultat)
                   

            
        
s1 = Solution()
print (s1.findMaxForm(["10","0","1"], 1, 1))
# Out:
# list [2, 1, 1]
# stop_for in while None
# [2, 1, 1] listLenghtValue
# stop_for in element boucle None
# len element 2
# smallest 1
#
# num one 0
# num zero 0
#
# stop_for in element boucle None
# len element 1
# smallest 1
# number treat//////////// 0
# elementstr ['10', '0', '1']
# number in number treat 0
# add zero
#
# smallest in for 1
# list leght [2, 1, 1]
# strList ['10', '0', '1']
# elment str 0
#
#
# num one 0
# num zero 1
#
# stop_for in element boucle None
# len element 1
# smallest 1
# number treat//////////// 1
# elementstr ['10', '0', '1']
# number in number treat 1
# add one
# we break because of num
#
# smallest in for 1
# list leght [2, 1]
# strList ['10', '1']
# elment str 1
#
#
# num one 1
# num zero 1
#
# stop_for in while True
# 2
